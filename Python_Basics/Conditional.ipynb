# %%
# conditional 
# 1st Question
marks = int(input(print("Enter marks : ")))
if marks >= 80:
    print("you will be a part of A0 batch")
elif marks >= 60 and marks <80 :
    print("you will be a part of A1 batch")
elif marks >= 40 and marks <60 :
    print("you will be part of A2 batch")
else :
    print("you will be a part of A3 batch")
# Out:
# Enter marks :
# None 656
# you will be a part of A0 batch

# %%
# conditional 
# 2nd Question
price = int(input(print("Enter price = ")))
if price > 1000:
    print("I will not purchase")
else :
    print("I will purchase")
# Out:
# Enter price =
# None 7000
# I will not purchase

# %%
# conditional 
# Nested if - else
# 3rd Question
price = int(input(print("Enter price = ")))
if price > 1000:
    print("I will not purchase")
    if price > 5000:
        print("Bruh this is too much")
else :
    print("I will purchase")
# Out:
# Enter price =
# None 8000
# I will not purchase
# Bruh this is too much
