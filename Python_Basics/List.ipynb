# %%
# A list is used to store mulitple data types in a single variable.
l = [1,345,45,"Nikhil",True,5+7j,345.456]

# %%
type(l)
# Out:
# list

# %%
l[1]
# Out:
# 345

# %%
l[0]
# Out:
# 1

# %%
l[2]
# Out:
# 45

# %%
l[2,3,4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 l[2,3,4]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
l[::1]
# Out:
# [1, 345, 45, 'Nikhil', True, (5+7j), 345.456]

# %%
l[0:5:1]
# Out:
# [1, 345, 45, 'Nikhil', True]

# %%
l[0:3:1]
# Out:
# [1, 345, 45]

# %%
l[-1]
# Out:
# 345.456

# %%
l[-1:-8]
# Out:
# []

# %%
l[-1:-7]
# Out:
# []

# %%
l[-1:-8:-1]
# Out:
# [345.456, (5+7j), True, 'Nikhil', 45, 345, 1]

# %%
l[-3]
# Out:
# True

# %%
l[-2]
# Out:
# (5+7j)

# %%
l[-4]
# Out:
# 'Nikhil'

# %%
l[::-1]
# Out:
# [345.456, (5+7j), True, 'Nikhil', 45, 345, 1]

# %%
l[::1]
# Out:
# [1, 345, 45, 'Nikhil', True, (5+7j), 345.456]

# %%
l[0:8:2]
# Out:
# [1, 45, True, 345.456]

# %%
l[0:8:2+1]
# Out:
# [1, 'Nikhil', 345.456]

# %%
l[::2]
# Out:
# [1, 45, True, 345.456]

# %%
s = "pwskills"

# %%
s = ["pwskills"]

# %%
l+s
# Out:
# [1, 345, 45, 'Nikhil', True, (5+7j), 345.456, 'pwskills']

# %%
l[3]
# Out:
# 'Nikhil'

# %%
type(l[3])
# Out:
# str

# %%
l[3][0:2]
# Out:
# 'Ni'

# %%
 l[5][0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 l[5][0:2]
#
# TypeError: 'complex' object is not subscriptable

# %%
l
# Out:
# [1, 345, 45, 'Nikhil', True, (5+7j), 345.456]

# %%
l[5][0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 l[5][0:2]
#
# TypeError: 'complex' object is not subscriptable

# %%
l[4][0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 l[4][0:2]
#
# TypeError: 'bool' object is not subscriptable

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l[5.real]
# Out:
#   Cell In[35], line 1
#     l[5.real]
#        ^
# SyntaxError: invalid decimal literal

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
str(l[4][0:2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 str(l[4][0:2])
#
# TypeError: 'bool' object is not subscriptable

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l
# Out:
# [1, 345, 45, 'Nikhil', True, (5+7j), 345.456]

# %%
student = ["nikhil",18,"Udaipur"]

# %%
stduent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 stduent
#
# NameError: name 'stduent' is not defined

# %%
print(student)
# Out:
# ['nikhil', 18, 'Udaipur']

# %%
student[::1]
# Out:
# ['nikhil', 18, 'Udaipur']

# %%
student = ["man",5,67,"Rajasthan"]

# %%
print(student)
# Out:
# ['man', 5, 67, 'Rajasthan']

# %%
one = ["yes"]

# %%
type(student)
# Out:
# list

# %%
student + one
# Out:
# ['man', 5, 67, 'Rajasthan', 'yes']

# %%
student.append("YEAH")

# %%
student
# Out:
# ['man', 5, 67, 'Rajasthan', 'YEAH']

# %%
student.reverse()

# %%
student
# Out:
# ['YEAH', 'Rajasthan', 67, 5, 'man']

# %%
student.insert(4,"udaipur")

# %%
student
# Out:
# ['YEAH', 'Rajasthan', 67, 5, 'udaipur', 'man']

# %%
 student.insert(4,"jaipur")

# %%
student
# Out:
# ['YEAH', 'Rajasthan', 67, 5, 'jaipur', 'udaipur', 'man']

# %%
student.reverse()

# %%
student
# Out:
# ['man', 'udaipur', 'jaipur', 5, 67, 'Rajasthan', 'YEAH']

# %%
student[1:3]
# Out:
# ['udaipur', 'jaipur']

# %%
List =[34,2,54,654,243,454,3434,]

# %%
print(List)
# Out:
# [34, 2, 54, 654, 243, 454, 3434]

# %%
List.sort()

# %%
List
# Out:
# [2, 34, 54, 243, 454, 654, 3434]

# %%
List.append(90)

# %%
List
# Out:
# [2, 34, 54, 243, 454, 654, 3434, 90]

# %%
List.sort()

# %%
List
# Out:
# [2, 34, 54, 90, 243, 454, 654, 3434]

# %%
List.reverse()

# %%
List
# Out:
# [3434, 654, 454, 243, 90, 54, 34, 2]

# %%
List.sort(reverse = True)

# %%
List
# Out:
# [3434, 654, 454, 243, 90, 54, 34, 2]

# %%
Liist = ["Banana","Litchi","apple","guava"]

# %%
Liist.sort()

# %%
Liist
# Out:
# ['Banana', 'Litchi', 'apple', 'guava']

# %%
Liist.sort(reverse = True)

# %%
Liist
# Out:
# ['guava', 'apple', 'Litchi', 'Banana']

# %%
Liist.sort()

# %%
Liist
# Out:
# ['Banana', 'Litchi', 'apple', 'guava']

# %%
 ins = [1,4,6,65,4,4,]

# %%
ins.insert(3,7)

# %%
ins
# Out:
# [1, 4, 6, 7, 65, 4, 4]

# %%
ins.remove(65)

# %%
ins
# Out:
# [1, 4, 6, 7, 4, 4]

# %%
ins.pop(5)
# Out:
# 4

# %%
ins
# Out:
# [1, 4, 6, 7, 4]

# %%
ins.sort
# Out:
# <function list.sort(*, key=None, reverse=False)>

# %%
ins.sort
# Out:
# <function list.sort(*, key=None, reverse=False)>

# %%
ins
# Out:
# [1, 4, 6, 7, 4]

# %%
ins.sort()

# %%
ins
# Out:
# [1, 4, 4, 6, 7]

# %%
ins.pop(1)
# Out:
# 4

# %%
ins
# Out:
# [1, 4, 6, 7]
