# %%
dict = {
    "name" : "Nikhil",
    "cgpa" : 9.6,
    "marks" : [98,97,95],
}

# %%
print(dict)
# Out:
# {'name': 'Nikhil', 'cgpa': 9.6, 'marks': [98, 97, 95]}

# %%
type(dict)
# Out:
# dict

# %%
print(dict["name"])
# Out:
# Nikhil

# %%
print(dict["cgpa"])
# Out:
# 9.6

# %%
print(dict["marks"])
# Out:
# [98, 97, 95]

# %%
dict["marks"] = [99,98,97]

# %%
print(dict["marks"])
# Out:
# [99, 98, 97]

# %%
print(dict.keys())
# Out:
# dict_keys(['name', 'cgpa', 'marks'])

# %%
print(dict.values())
# Out:
# dict_values(['Nikhil', 9.6, [99, 98, 97]])

# %%
print(dict.items())
# Out:
# dict_items([('name', 'Nikhil'), ('cgpa', 9.6), ('marks', [99, 98, 97])])

# %%
print(dict.get("name"))
# Out:
# Nikhil

# %%
dict.update({"city" : "Udaipur"})

# %%
print(dict)
# Out:
# {'name': 'Nikhil', 'cgpa': 9.6, 'marks': [99, 98, 97], 'city': 'Udaipur'}

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
di = {"name ": "Nikhil", "number": 123}

# %%
di
# Out:
# {'name ': 'Nikhil', 'number': 123}

# %%
d3 = {234 : "sudh" , 'sername' : "kumar",True :7684638}

# %%
d3[1]
# Out:
# 7684638

# %%
d3['sername']
# Out:
# 'kumar'

# %%
d4 = {'name' : "soon", 'mail' : 'njhbjhc@gmail.com', "name" : "nikhil"}

# %%
d4["name"]
# Out:
# 'nikhil'

# %%
 d5 = {"Company" : "Nikhil Infotech" , "Course" : ["web dev","data science","system design"]}

# %%
print(d5)
# Out:
# {'Company': 'Nikhil Infotech', 'Course': ['web dev', 'data science', 'system design']}

# %%
d5
# Out:
# {'Company': 'Nikhil Infotech',
#  'Course': ['web dev', 'data science', 'system design']}

# %%
type(d5)
# Out:
# dict

# %%
d5['Course'][2]
# Out:
# 'system design'

# %%
d6 = {"number" : [3,4,53,22,32,43,] , "assignments" : (4,3,4,3,2,3),"Launch_date" : [23,24,5,4,3]}

# %%
d6["Launch_date"][3]
# Out:
# 4

# %%
d6["number"][3]
# Out:
# 22

# %%
d6
# Out:
# {'number': [3, 4, 53, 22, 32, 43],
#  'assignments': (4, 3, 4, 3, 2, 3),
#  'Launch_date': [23, 24, 5, 4, 3]}

# %%
dict = {}

# %%
type(dict)
# Out:
# dict

# %%
num = {1,2,3,3}

# %%
type(num)
# Out:
# set

# %%
num.length()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 num.length()
#
# AttributeError: 'set' object has no attribute 'length'

# %%
num
# Out:
# {1, 2, 3}

# %%
d6 = {"number" : [3,4,53,22,32,43,] , "assignments" : (4,3,4,3,2,3),"Launch_date" : [23,24,5,4,3]}

# %%
d6["Launch_date"][4] # Slicing or extracting -> finding 3 from Launch date
# Out:
# 3

# %%
# adding new key to dictionary d6
d6["mentor"] = ["sudhanshu sir" , "krish sir" , "anurag sir " , "hyder sir"]

# %%
print(d6) # done
# Out:
# {'number': [3, 4, 53, 22, 32, 43], 'assignments': (4, 3, 4, 3, 2, 3), 'Launch_date': [23, 24, 5, 4, 3], 'mentor': ['sudhanshu sir', 'krish sir', 'anurag sir ', 'hyder sir']}

# %%
#deleting a key
del d6["number"]

# %%
print(d6) # done
# Out:
# {'assignments': (4, 3, 4, 3, 2, 3), 'Launch_date': [23, 24, 5, 4, 3], 'mentor': ['sudhanshu sir', 'krish sir', 'anurag sir ', 'hyder sir']}

# %%
# it finds all keys in dictionary
d6.keys()
# Out:
# dict_keys(['assignments', 'Launch_date', 'mentor'])

# %%
# Converting dictionary into list
list(d6.keys())
# Out:
# ['assignments', 'Launch_date', 'mentor']

# %%
# After Converting a dictionary into list
# we can perfrom slicing like this
d6["assignments"][::]
# Out:
# (4, 3, 4, 3, 2, 3)

# %%
#key or values extracting
d6.items()
# Out:
# dict_items([('assignments', (4, 3, 4, 3, 2, 3)), ('Launch_date', [23, 24, 5, 4, 3]), ('mentor', ['sudhanshu sir', 'krish sir', 'anurag sir ', 'hyder sir'])])

# %%
list(d6.items())
# Out:
# [('assignments', (4, 3, 4, 3, 2, 3)),
#  ('Launch_date', [23, 24, 5, 4, 3]),
#  ('mentor', ['sudhanshu sir', 'krish sir', 'anurag sir ', 'hyder sir'])]

# %%
# deleting using pop function
d6.pop("assignments")
# Out:
# (4, 3, 4, 3, 2, 3)

# %%
# done
print(list(d6))
# Out:
# ['Launch_date', 'mentor']
