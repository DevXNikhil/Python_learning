# %%
Tup = (1,2,3)

# %%
Tup
# Out:
# (1, 2, 3)

# %%
type(Tup)
# Out:
# tuple

# %%
print(Tup[0])
# Out:
# 1

# %%
Tup[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Tup[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
Tup = (3,3,4,5,6,7)

# %%
 print(Tup[::])
# Out:
# (3, 3, 4, 5, 6, 7)

# %%
Tup.index(4)
# Out:
# 2

# %%
Tup.count(3)
# Out:
# 2

# %%
 tupl= ("A","B","C","A","C","B","C","B","A","C","A","B")

# %%
tupl.count("A")
# Out:
# 4

# %%
tupl.count("B")
# Out:
# 4

# %%
tupl.count("C")
# Out:
# 4

# %%
grade = ["A","B","C","A","C","B","C","B","A","C","A","B"]

# %%
grade.sort()

# %%
grade
# Out:
# ['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'C', 'C', 'C', 'C']

# %%
grade.reverse()

# %%
grade
# Out:
# ['C', 'C', 'C', 'C', 'B', 'B', 'B', 'B', 'A', 'A', 'A', 'A']
